# %%
import pandas as pd

df = pd.read_csv("DataCoSupplyChainDataset.csv", encoding="latin-1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
#  12  Customer Fname                 180519 non-null  object
#  13  Customer Id                    180519 non-null  int64
#  14  Customer Lname                 180511 non-null  object
#  15  Customer Password              180519 non-null  object
#  16  Customer Segment               180519 non-null  object
#  17  Customer State                 180519 non-null  object
#  18  Customer Street                180519 non-null  object
#  19  Customer Zipcode               180516 non-null  float64
#  20  Department Id                  180519 non-null  int64
#  21  Department Name                180519 non-null  object
#  22  Latitude                       180519 non-null  float64
#  23  Longitude                      180519 non-null  float64
#  24  Market                         180519 non-null  object
#  25  Order City                     180519 non-null  object
#  26  Order Country                  180519 non-null  object
#  27  Order Customer Id              180519 non-null  int64
#  28  order date (DateOrders)        180519 non-null  object
#  29  Order Id                       180519 non-null  int64
#  30  Order Item Cardprod Id         180519 non-null  int64
#  31  Order Item Discount            180519 non-null  float64
#  32  Order Item Discount Rate       180519 non-null  float64
#  33  Order Item Id                  180519 non-null  int64
#  34  Order Item Product Price       180519 non-null  float64
#  35  Order Item Profit Ratio        180519 non-null  float64
#  36  Order Item Quantity            180519 non-null  int64
#  37  Sales                          180519 non-null  float64
#  38  Order Item Total               180519 non-null  float64
#  39  Order Profit Per Order         180519 non-null  float64
#  40  Order Region                   180519 non-null  object
#  41  Order State                    180519 non-null  object
#  42  Order Status                   180519 non-null  object
#  43  Order Zipcode                  24840 non-null   float64
#  44  Product Card Id                180519 non-null  int64
#  45  Product Category Id            180519 non-null  int64
#  46  Product Description            0 non-null       float64
#  47  Product Image                  180519 non-null  object
#  48  Product Name                   180519 non-null  object
#  49  Product Price                  180519 non-null  float64
#  50  Product Status                 180519 non-null  int64
#  51  shipping date (DateOrders)     180519 non-null  object
#  52  Shipping Mode                  180519 non-null  object
# dtypes: float64(15), int64(14), object(24)
# memory usage: 73.0+ MB

# %%
df["start_node"] = df["Customer City"] + "_" + df["Customer Country"]
df["end_node"] = df["Order City"] + "_" + df["Order Country"]
nodes = set(df["start_node"].unique()).union(df["end_node"].unique())
nodes
# Out:
# {'Walsall_Reino Unido',
#  'Hacienda Heights_EE. UU.',
#  'Cumbernauld_Reino Unido',
#  'Saint-Louis_Senegal',
#  'Gilroy_EE. UU.',
#  'Onitsha_Nigeria',
#  'Mechanicsburg_EE. UU.',
#  'Calamba_Filipinas',
#  'Santa Cruz de la Sierra_Bolivia',
#  'Chesterfield_Reino Unido',
#  'Smyrna_EE. UU.',
#  'Chatham_Reino Unido',
#  'Ichalkaranji_India',
#  'Paulista_Brasil',
#  'Bilbao_España',
#  'Carson_EE. UU.',
#  'Palma Soriano_Cuba',
#  'Bangor_Estados Unidos',
#  'Balneário Camboriú_Brasil',
#  "Donets'k_Ucrania",
#  'Reno_Estados Unidos',
#  'Carol Stream_EE. UU.',
#  'Paris_Francia',
#  'Yangzhou_China',
#  'Vijayawada_India',
#  'Kigoma_Tanzania',
#  'Massapequa_EE. UU.',
#  'Palermo_Italia',
#  'Soledad Díez Gutiérrez_México',
#  'Huaihua_China',
#  'El Monte_EE. UU.',
#  'East London_SudAfrica',
#  'Newark_EE. UU.',
#  'Warri_Nigeria',
#  'Ensenada_México',
#  'Langfang_China',
#  'Kalyan_India',
#  'Lakewood_Estados Unidos',
#  'Nice_Francia',
#  'Lille_Francia',
#  'Alanya_Turquía',
#  'Mauá_Brasil',
#  'Tanggu_China',
#  'Centurion_SudAfrica',
#  'Tourcoing_Francia',
#  'Panama City_Panamá',
#  'Torbat-e Heydariyeh_Irán',
#  'Newcastle upon Tyne_Reino Unido',
#  'Cumaná_Venezuela',
#  'Halluin_Francia',
#  'Deyang_China',
#  'Hod HaSharon_Israel',
#  'Bunbury_Australia',
#  'Hampton_EE. UU.',
#  'Kettering_Reino Unido',
#  'Swindon_Reino Unido',
#  'Haikou_China',
#  'Wyandotte_EE. UU.',
#  'El Paso_EE. UU.',
#  'Tepic_México',
#  'Plano_EE. UU.',
#  'Wellington_Nueva Zelanda',
#  'Ningbo_China',
#  'Indaial_Brasil',
#  'Katowice_Polonia',
#  'Kananga_República Democrática del Congo',
#  'Zabol_Irán',
#  'Freeport_EE. UU.',
#  'Lázaro Cárdenas_México',
#  'Fortaleza_Brasil',
#  'Park Ridge_Estados Unidos',
#  'Greenwood_Estados Unidos',
#  'Arlington_Estados Unidos',
#  'Masaya_Nicaragua',
#  'Koumra_Chad',
#  'Port Said_Egipto',
#  'Bountiful_EE. UU.',
#  'Teramo_Italia',
#  'Rancagua_Chile',
#  'Ibiúna_Brasil',
#  'Kankan_Guinea',
#  'Houilles_Francia',
#  'Berne_Suiza',
#  'Nellore_India',
#  'Wadi as Sir_Jordania',
#  'El Cajon_Estados Unidos',
#  'Barranquilla_Colombia',
#  'Parker_Estados Unidos',
#  'Petapa_Guatemala',
#  'Hamadán_Irán',
#  'Amarillo_EE. UU.',
#  'Colombes_Francia',
#  'Kortrijk_Bélgica',
#  'Goleta_EE. UU.',
#  'Dubuque_Estados Unidos',
#  'Libreville_Gabón',
#  'Baden-Baden_Alemania',
#  'Unna_Alemania',
#  'Laval_Canada',
#  'Viterbo_Italia',
#  'Fargo_Estados Unidos',
#  'Mauguio_Francia',
#  'Phoenix_Estados Unidos',
#  'Járkov_Ucrania',
#  'Paita_Perú',
#  'Zaozhuang_China',
#  'Potosí_Bolivia',
#  'Santa Fe_EE. UU.',
#  'Fuenlabrada_España',
#  'North Hollywood_EE. UU.',
#  'Allentown_Estados Unidos',
#  'Weihai_China',
#  'São Pedro da Aldeia_Brasil',
#  'Rostock_Alemania',
#  'Laval_Francia',
#  'Zhenjiang_China',
#  'Les Herbiers_Francia',
#  'Guatire_Venezuela',
#  'Bastia_Francia',
#  'Clearfield_EE. UU.',
#  'Munster_Alemania',
#  'Ipoh_Malasia',
#  'La Baule-Escoublac_Francia',
#  'Chico_Estados Unidos',
#  'Garbsen_Alemania',
#  'Kindu_República Democrática del Congo',
#  'Richardson_EE. UU.',
#  'Longueuil_Canada',
#  'Nacka_Suecia',
#  'Valledupar_Colombia',
#  'Passo Fundo_Brasil',
#  'Potenza_Italia',
#  'Watertown_Estados Unidos',
#  'Coulommiers_Francia',
#  'West Palm Beach_Estados Unidos',
#  'Rijeka_Croacia',
#  'Resita_Rumania',
#  'Behbahan_Irán',
#  'Pazardzhik_Bulgaria',
#  'Bristol_EE. UU.',
#  'Bangkok_Tailandia',
#  'Islamabad_Pakistán',
#  'Cluj-Napoca_Rumania',
#  'Massy_Francia',
#  'Gorakhpur_India',
#  'Barneveld_Países Bajos',
#  'Pontoise_Francia',
#  'Chaumont_Francia',
#  'Baku_Azerbaiyán',
#  'Tracy_EE. UU.',
#  'Farroupilha_Brasil',
#  'Saint-Ouen_Francia',
#  'Toms River_EE. UU.',
#  'Laguna Niguel_Estados Unidos',
#  'Barreiras_Brasil',
#  'Ganganagar_India',
#  'Beykoz_Turquía',
#  'Saint-Priest_Francia',
#  'Shijiazhuang_China',
#  'Pindamonhangaba_Brasil',
#  'Victorville_EE. UU.',
#  'Volksrust_SudAfrica',
#  'Delmenhorst_Alemania',
#  'Yibuti_Yibuti',
#  'Bialystok_Polonia',
#  'Brasília_Brasil',
#  'Quixadá_Brasil',
#  'Águas Lindas de Goiás_Brasil',
#  'Arkhangelsk_Rusia',
#  'Lindenhurst_EE. UU.',
#  'Monrovia_Liberia',
#  'Oxford_Reino Unido',
#  'Concord_Estados Unidos',
#  'Acayucan_México',
#  'Morogoro_Tanzania',
#  'San Mateo_Estados Unidos',
#  'Lahore_Pakistán',
#  'Antakya_Turquía',
#  'Lynn_EE. UU.',
#  'Navegantes_Brasil',
#  'Ayacucho_Perú',
#  'Kuito_Angola',
#  'Guacara_Venezuela',
#  'Chingola_Zambia',
#  'Montbrison_Francia',
#  'Lutz_EE. UU.',
#  'Zapopan_México',
#  'Izmir_Turquía',
#  'Borken_Alemania',
#  'Kartal_Turquía',
#  'Manila_Filipinas',
#  'Guadalajara_México',
#  'Canoas_Brasil',
#  'Rach Gia_Vietnam',
#  'West Jordan_EE. UU.',
#  'Armidale_Australia',
#  'Ufa_Rusia',
#  'Pleasant Grove_Estados Unidos',
#  'Budënnovsk_Rusia',
#  'Bishkek_Kirguistán',
#  'Maisons-Alfort_Francia',
#  'Managua_Nicaragua',
#  'Folsom_EE. UU.',
#  'Srinagar_India',
#  'Durham_Estados Unidos',
#  'Herne_Alemania',
#  'Macon_Estados Unidos',
#  'Zhuzhou_China',
#  'Elkhart_Estados Unidos',
#  'Dundalk_EE. UU.',
#  'Oslo_Noruega',
#  'Donghai_China',
#  'Bandirma_Turquía',
#  'Kazerun_Irán',
#  'Quebec_Canada',
#  'Ilo_Perú',
#  'Ancona_Italia',
#  'Rivera_Uruguay',
#  'Sukkur_Pakistán',
#  'Vallejo_Estados Unidos',
#  'Fuengirola_España',
#  'Andover_Estados Unidos',
#  'Morganton_EE. UU.',
#  'Vientiane_Laos',
#  'Cary_Estados Unidos',
#  'Sugar Land_EE. UU.',
#  'Shuangyashan_China',
#  'Winnetka_EE. UU.',
#  'Alessandria_Italia',
#  'Cessnock_Australia',
#  'Jonesboro_Estados Unidos',
#  'Sète_Francia',
#  'Tauranga_Nueva Zelanda',
#  'Lormont_Francia',
#  'Mission_EE. UU.',
#  'Puebla_México',
#  'Louisville_Estados Unidos',
#  'Rockhampton_Australia',
#  'Lens_Francia',
#  'Redwood City_Estados Unidos',
#  'Osijek_Croacia',
#  'La Habra_EE. UU.',
#  'Takatsuki_Japón',
#  'Vitória da Conquista_Brasil',
#  'Santa Ana_EE. UU.',
#  'Estepona_España',
#  'Pensacola_Estados Unidos',
#  'Abadan_Irán',
#  'Colombo_Sri Lanka',
#  'Cajamarca_Perú',
#  'Aberdeen_Estados Unidos',
#  'Broken Arrow_Estados Unidos',
#  'Campina Grande_Brasil',
#  'Hanford_EE. UU.',
#  'Fresno_Estados Unidos',
#  'Ibirité_Brasil',
#  'Chorzow_Polonia',
#  'Urbandale_Estados Unidos',
#  'Vigo_España',
#  'Chester_Reino Unido',
#  'Gaomi_China',
#  'Pekalongan_Indonesia',
#  'Nzerekore_Guinea',
#  'Los Angeles_Estados Unidos',
#  'Albuquerque_Estados Unidos',
#  'Roanne_Francia',
#  'Chillán_Chile',
#  'Varna_Bulgaria',
#  'Juliaca_Perú',
#  'Fontenay-le-Comte_Francia',
#  'Ujjain_India',
#  'Kaifeng_China',
#  'Hereford_Reino Unido',
#  'Odivelas_Portugal',
#  'Lusaka_Zambia',
#  'Khorramshahr_Irán',
#  'Khasavyurt_Rusia',
#  'Pitalito_Colombia',
#  'Santa Clara_EE. UU.',
#  'Delgado_El Salvador',
#  'Great Yarmouth_Reino Unido',
#  'Teherán_Irán',
#  'Maxixe_Mozambique',
#  'Oyonnax_Francia',
#  'Pouso Alegre_Brasil',
#  'Bellevue_Estados Unidos',
#  'Disuq_Egipto',
#  'Ocotlán_México',
#  'Musoma_Tanzania',
#  'Naumburg_Alemania',
#  'Massillon_EE. UU.',
#  'Boca Raton_Estados Unidos',
#  'Laghouat_Argelia',
#  'Pernik_Bulgaria',
#  'Basra_Irak',
#  'Poços de Caldas_Brasil',
#  'O Fallon_EE. UU.',
#  'Madera_EE. UU.',
#  'Annapolis_EE. UU.',
#  'Bourgoin-Jallieu_Francia',
#  'Aligarh_India',
#  'Algonquin_EE. UU.',
#  'Portland_Estados Unidos',
#  'Namangán_Uzbekistán',
#  'Beloit_EE. UU.',
#  'Tupã_Brasil',
#  'Foggia_Italia',
#  'Daly City_EE. UU.',
#  'Sarreguemines_Francia',
#  'Uithoorn_Países Bajos',
#  'Antananarivo_Madagascar',
#  'Philadelphia_Estados Unidos',
#  'Napa_EE. UU.',
#  'Perth Amboy_Estados Unidos',
#  'Citrus Heights_Estados Unidos',
#  'Whakatane_Nueva Zelanda',
#  'San Francisco_Estados Unidos',
#  'Neuwied_Alemania',
#  'Whyalla_Australia',
#  'Bremen_Alemania',
#  'Eunápolis_Brasil',
#  'Liverpool_Reino Unido',
#  'Mufulira_Zambia',
#  'Jacksonville_Estados Unidos',
#  'Giyani_SudAfrica',
#  'Verona_Italia',
#  'Fort-de-France_Martinica',
#  'Mijas_España',
#  'Tokio_Japón',
#  'Tongi_Bangladés',
#  'Daegu_Corea del Sur',
#  'Constanza_Rumania',
#  'Hattingen_Alemania',
#  'Southampton_Reino Unido',
#  'Maroua_Camerún',
#  'Hautmont_Francia',
#  'La Roche-sur-Yon_Francia',
#  'Piedecuesta_Colombia',
#  'Vadodara_India',
#  'Taizhou_China',
#  'Chapel Hill_EE. UU.',
#  'Palmerston North_Nueva Zelanda',
#  'Beaune_Francia',
#  'Al Manaqil_Sudán',
#  'Logan_Estados Unidos',
#  'Niamey_Níger',
#  'Rajshahi_Bangladés',
#  'Wattrelos_Francia',
#  'Yaroslavl_Rusia',
#  'Limeira_Brasil',
#  'Cholet_Francia',
#  'Mamak_Turquía',
#  'Kafr ad Dawwar_Egipto',
#  'Hamamatsu_Japón',
#  'Hangu_China',
#  'Meriden_Estados Unidos',
#  'Carrollton_EE. UU.',
#  'Baldwin Park_EE. UU.',
#  'Villiers-sur-Marne_Francia',
#  'Bagamoyo_Tanzania',
#  'Idfu_Egipto',
#  'Elyria_EE. UU.',
#  'Denton_EE. UU.',
#  'Ann Arbor_Estados Unidos',
#  'Maputo_Mozambique',
#  'Borazjan_Irán',
#  'Cabo Frio_Brasil',
#  "Luts'k_Ucrania",
#  'Trapani_Italia',
#  'Luoyang_China',
#  'Stanger_SudAfrica',
#  'Wuhan_China',
#  'Richmond_Canada',
#  'Denver_Estados Unidos',
#  "Usol'ye-Sibirskoye_Rusia",
#  'Mansfield_Estados Unidos',
#  'Wuchuan_China',
#  'Lynnwood_EE. UU.',
#  'Santo André_Brasil',
#  'Krasnyy Luch_Ucrania',
#  'Safi_Marruecos',
#  'Frankfurt_Alemania',
#  'Puerto Vallarta_México',
#  'Wuchang_China',
#  'Kaspiysk_Rusia',
#  'Novo Cruzeiro_Brasil',
#  'Frontera_México',
#  'Antsiranana_Madagascar',
#  'Greensboro_Estados Unidos',
#  'Nanning_China',
#  'Oosterhout_Países Bajos',
#  'Irkutsk_Rusia',
#  'Apopka_EE. UU.',
#  'Hayange_Francia',
#  'Xichang_China',
#  'Cuneo_Italia',
#  'Mardin_Turquía',
#  'Redondo Beach_Estados Unidos',
#  'Recife_Brasil',
#  'Feira de Santana_Brasil',
#  'San Andrés Tuxtla_México',
#  'Ouagadougou_Burkina Faso',
#  'Rio Branco_Brasil',
#  'Delft_Países Bajos',
#  'Hanoi_Vietnam',
#  'Odense_Dinamarca',
#  'Woodstock_Estados Unidos',
#  'Lanzhou_China',
#  'Mtwara_Tanzania',
#  'Firozabad_India',
#  'Los Patios_Colombia',
#  'Pemba_Mozambique',
#  'Greeley_EE. UU.',
#  'Huadian_China',
#  'Jacobina_Brasil',
#  'Lubumbashi_República Democrática del Congo',
#  'Chimbote_Perú',
#  'Luxemburgo_Luxemburgo',
#  'Rego Park_EE. UU.',
#  'Gujranwala_Pakistán',
#  'Saumur_Francia',
#  'Tipitapa_Nicaragua',
#  'Clementon_EE. UU.',
#  'North York_Canada',
#  'Baruta_Venezuela',
#  'Floridablanca_Colombia',
#  'Sonsonate_El Salvador',
#  'Bursa_Turquía',
#  'Pertuis_Francia',
#  'Apatzingán de la Constitución_México',
#  'Ipiales_Colombia',
#  'Nottingham_Reino Unido',
#  'Solapur_India',
#  'Cancún_México',
#  'Dunstable_Reino Unido',
#  'Halle_Alemania',
#  'Neuilly-Plaisance_Francia',
#  'Passaic_Estados Unidos',
#  'Amatitlán_Guatemala',
#  'Morristown_Estados Unidos',
#  'Leominster_Estados Unidos',
#  'Aguadilla_Puerto Rico',
#  'Grodno_Bielorrusia',
#  'Qena_Egipto',
#  'Verdun_Francia',
#  'Jaboticabal_Brasil',
#  'Penglai_China',
#  'Urganch_Uzbekistán',
#  'Bandar-e Anzali_Irán',
#  'Civitavecchia_Italia',
#  'Ilorin_Nigeria',
#  'Nha Trang_Vietnam',
#  'Bayeux_Francia',
#  'Madison_EE. UU.',
#  'Bekasi_Indonesia',
#  'Suffolk_Estados Unidos',
#  'Carquefou_Francia',
#  'Atlanta_EE. UU.',
#  'Corlu_Turquía',
#  'Perpignan_Francia',
#  'Neuilly-sur-Seine_Francia',
#  'Ciego de Ávila_Cuba',
#  'Melchor Ocampo_México',
#  'Sakai_Japón',
#  'Billings_Estados Unidos',
#  'Summerville_EE. UU.',
#  'Changchun_China',
#  'Bethlehem_Estados Unidos',
#  'Chihuahua_México',
#  'Belgrade_Serbia',
#  'Las Pinas_Filipinas',
#  'Chincha Alta_Perú',
#  'Hampton_Estados Unidos',
#  'Heze_China',
#  'Argenteuil_Francia',
#  'Henrico_EE. UU.',
#  'Rize_Turquía',
#  'Kalemie_República Democrática del Congo',
#  'Sunderland_Reino Unido',
#  'Sincan_Turquía',
#  'Taverny_Francia',
#  'Plovdiv_Bulgaria',
#  'Lugoj_Rumania',
#  'Hamilton_Nueva Zelanda',
#  'Makeni_Sierra Leona',
#  'Matanzas_Cuba',
#  'Elk Grove_EE. UU.',
#  'Salvador_Brasil',
#  'Hoover_Estados Unidos',
#  'Garanhuns_Brasil',
#  'Eugene_EE. UU.',
#  'Aracaju_Brasil',
#  'Issy-les-Moulineaux_Francia',
#  'Koblenz_Alemania',
#  'Cedar Rapids_Estados Unidos',
#  'Longmont_Estados Unidos',
#  'Saint Paul_EE. UU.',
#  'Brownsville_EE. UU.',
#  'Lakeland_Estados Unidos',
#  'Al Mubarraz_Arabia Saudí',
#  'Bélgorod_Rusia',
#  'Agen_Francia',
#  'San Benito_EE. UU.',
#  'Givors_Francia',
#  'San Bernardo_Chile',
#  'Randers_Dinamarca',
#  'Greifswald_Alemania',
#  'Malambo_Colombia',
#  'Vineland_Estados Unidos',
#  'Xinshi_China',
#  'Loos_Francia',
#  'Barcelona_Venezuela',
#  'Zabrze_Polonia',
#  'Votuporanga_Brasil',
#  'Antalya_Turquía',
#  'Alice Springs_Australia',
#  'Salem_Estados Unidos',
#  'Bijie_China',
#  'Foligno_Italia',
#  'Eugene_Estados Unidos',
#  'Catonsville_EE. UU.',
#  'Auxerre_Francia',
#  'Westerville_EE. UU.',
#  'Harrogate_Reino Unido',
#  'San Pedro_Filipinas',
#  'Maiduguri_Nigeria',
#  'Camaragibe_Brasil',
#  'Polatsk_Bielorrusia',
#  'Montebello_Estados Unidos',
#  'Ipswich_Reino Unido',
#  'Oldham_Reino Unido',
#  'Las Rozas de Madrid_España',
#  'Barbacena_Brasil',
#  'Jhansi_India',
#  'Arvada_Estados Unidos',
#  'Buyukcekmece_Turquía',
#  'Juazeiro_Brasil',
#  'Sanliurfa_Turquía',
#  'Toledo_Estados Unidos',
#  'Richmond Hill_Canada',
#  'Amsterdam_Países Bajos',
#  'Aulnay-sous-Bois_Francia',
#  'Rajkot_India',
#  'Aew?l-li_Corea del Sur',
#  'St. Catharines_Canada',
#  'Zaporiyia_Ucrania',
#  'Jingmen_China',
#  'Lake Charles_Estados Unidos',
#  'Derbent_Rusia',
#  'North Tonawanda_EE. UU.',
#  'Nicoya_Costa Rica',
#  'Al Amarah_Irak',
#  'Guildford_Reino Unido',
#  'Ranchi_India',
#  'Powder Springs_EE. UU.',
#  'Béchar_Argelia',
#  'Mildura_Australia',
#  'Karlsruhe_Alemania',
#  'Bowling Green_EE. UU.',
#  'Hastings_Nueva Zelanda',
#  'Oyama_Japón',
#  'London_Canada',
#  'Parkville_EE. UU.',
#  'La Ceiba_Honduras',
#  'Londrina_Brasil',
#  'Puyang_China',
#  'Woking_Reino Unido',
#  'New Brunswick_EE. UU.',
#  'El Ejido_España',
#  'Neubrandenburg_Alemania',
#  'Pasto_Colombia',
#  'La Mesa_EE. UU.',
#  'Turku_Finlandia',
#  'Jequié_Brasil',
#  'Beni Suef_Egipto',
#  'Deva_Rumania',
#  'Shouguang_China',
#  'Glenview_EE. UU.',
#  'Brentwood_Estados Unidos',
#  'Tiflis_Georgia',
#  'Trenton_Estados Unidos',
#  'Genk_Bélgica',
#  'Tamarac_Estados Unidos',
#  'New Castle_Estados Unidos',
#  'Kanpur_India',
#  'Klaip?da_Lituania',
#  'Hanover_EE. UU.',
#  'Mobile_Estados Unidos',
#  'Libourne_Francia',
#  'Manizales_Colombia',
#  'Oriximiná_Brasil',
#  'Nuneaton_Reino Unido',
#  'Royal Oak_Estados Unidos',
#  'Faridabad_India',
#  'Offenburg_Alemania',
#  'Saint-Genis-Laval_Francia',
#  'Galway_Irlanda',
#  'Coimbra_Portugal',
#  'Ulhasnagar_India',
#  'Garland_Estados Unidos',
#  'Calama_Chile',
#  'Reynosa_México',
#  'Murfreesboro_Estados Unidos',
#  'Yuma_Estados Unidos',
#  'Fort Lauderdale_Estados Unidos',
#  'Yuma_EE. UU.',
#  'Jiangyan_China',
#  'Rustenburg_SudAfrica',
#  'Grove City_EE. UU.',
#  'Shanghái_China',
#  'Akron_Estados Unidos',
#  'East Lansing_EE. UU.',
#  'Gwynn Oak_EE. UU.',
#  'Beverly_Estados Unidos',
#  'Punta Arenas_Chile',
#  'Shihezi_China',
#  'Salinas_Estados Unidos',
#  'Al Khums_Libia',
#  'Stafford_Reino Unido',
#  'Miramar_México',
#  'La Chorrera_Panamá',
#  'Masjed Soleyman_Irán',
#  'Jaú_Brasil',
#  'Abha_Arabia Saudí',
#  'Garforth_Reino Unido',
#  'Fontainebleau_Francia',
#  'Lohne_Alemania',
#  'Ezhou_China',
#  'Choisy-le-Roi_Francia',
#  'Burnsville_EE. UU.',
#  'Anshun_China',
#  'Les Pavillons-sous-Bois_Francia',
#  'Salamanca_España',
#  'Bari_Italia',
#  'Damaturu_Nigeria',
#  'Huainan_China',
#  'Montauban_Francia',
#  'Guangzhou_China',
#  'Yokkaichi_Japón',
#  'Patiala_India',
#  'Lewisville_EE. UU.',
#  'Worthing_Reino Unido',
#  'Birigui_Brasil',
#  'Cheonan_Corea del Sur',
#  'Portici_Italia',
#  'Leeds_Reino Unido',
#  'Guasave_México',
#  'Plantation_Estados Unidos',
#  'Xintai_China',
#  'Torquay_Australia',
#  'Abbotsford_Canada',
#  'Santa Maria_Estados Unidos',
#  'Abilene_Estados Unidos',
#  'Karliova_Turquía',
#  'La Spezia_Italia',
#  'San Ignacio_Belice',
#  'Cherkasy_Ucrania',
#  'Conflans-Sainte-Honorine_Francia',
#  'Quevedo_Ecuador',
#  'Vigneux-sur-Seine_Francia',
#  'Novo Gama_Brasil',
#  'Harlingen_Estados Unidos',
#  'Mérida_México',
#  'Great Falls_Estados Unidos',
#  'New York_EE. UU.',
#  'Porterville_EE. UU.',
#  'Doha_Qatar',
#  'Krugersdorp_SudAfrica',
#  'Guntur_India',
#  'Zamora_España',
#  'Chittagong_Bangladés',
#  'Lida_Bielorrusia',
#  'Baní_República Dominicana',
#  'Bergen op Zoom_Países Bajos',
#  'Can Tho_Vietnam',
#  'Veracruz_México',
#  'Barranca_Perú',
#  'Riom_Francia',
#  'Caloocan_Filipinas',
#  'Gresham_Estados Unidos',
#  'Antofagasta_Chile',
#  'Santa Catarina_México',
#  'Denver_EE. UU.',
#  'Sheboygan_Estados Unidos',
#  'Launceston_Australia',
#  'Santa Rosa_Argentina',
#  'Gorgan_Irán',
#  'Linz_Austria',
#  'Puerto Montt_Chile',
#  'Levittown_EE. UU.',
#  'Caguas_Puerto Rico',
#  'Presidente Dutra_Brasil',
#  'Tempe_Estados Unidos',
#  'Marsa Matruh_Egipto',
#  'Crystal Lake_EE. UU.',
#  'Vichy_Francia',
#  'Shangyu_China',
#  'Commerce City_Estados Unidos',
#  'Heerlen_Países Bajos',
#  'Zunyi_China',
#  'Redditch_Reino Unido',
#  'Acuña_México',
#  'Ventura_EE. UU.',
#  'Lençóis Paulista_Brasil',
#  'Jurema_Brasil',
#  'Lewiston_Estados Unidos',
#  'Broken Arrow_EE. UU.',
#  'Cajazeiras_Brasil',
#  'Villeneuve-Saint-Georges_Francia',
#  'Saint-Quentin_Francia',
#  'Osasco_Brasil',
#  'Sheffield_Reino Unido',
#  'Mogadishu_Somalia',
#  'Vacaria_Brasil',
#  'Batman_Turquía',
#  'Wilson_Estados Unidos',
#  'Pilsen_República Checa',
#  'New Castle_EE. UU.',
#  'Hartlepool_Reino Unido',
#  'Bangalore_India',
#  'Slupsk_Polonia',
#  'Yacuiba_Bolivia',
#  'Corbeil-Essonnes_Francia',
#  'Padang_Indonesia',
#  'Renqiu_China',
#  'Huntington Beach_Estados Unidos',
#  'Hamilton_Canada',
#  'Melitopol_Ucrania',
#  'Holguín_Cuba',
#  'North Charleston_Estados Unidos',
#  'Wuhai_China',
#  'La Teste-de-Buch_Francia',
#  'Shahjahanpur_India',
#  'Arusha_Tanzania',
#  'Daejeon_Corea del Sur',
#  'Jeddah_Arabia Saudí',
#  'Meyzieu_Francia',
#  'Rochester_Estados Unidos',
#  'Kilis_Turquía',
#  'Mubi_Nigeria',
#  'Balikesir_Turquía',
#  'Saqqez_Irán',
#  'Frontignan_Francia',
#  'San Clemente_Estados Unidos',
#  'Fargo_EE. UU.',
#  'Penedo_Brasil',
#  'Highland Park_EE. UU.',
#  'Xuanhua_China',
#  'Linyi_China',
#  'Criciúma_Brasil',
#  'Coachella_Estados Unidos',
#  'Orem_Estados Unidos',
#  'Quetzaltenango_Guatemala',
#  'Yazd_Irán',
#  'Les Ulis_Francia',
#  'Papakura_Nueva Zelanda',
#  'Franconville_Francia',
#  'Hinckley_Reino Unido',
#  'Emden_Alemania',
#  'Bayonne_Francia',
#  'Normal_Estados Unidos',
#  'Nijmegen_Países Bajos',
#  'Orlando_Estados Unidos',
#  'Apple Valley_Estados Unidos',
#  'Smyrna_Estados Unidos',
#  'Chaguanas_Trinidad y Tobago',
#  'Marbella_España',
#  'Qarshi_Uzbekistán',
#  'Tivoli_Italia',
#  'Igarassu_Brasil',
#  'Roseville_Estados Unidos',
#  'Bhilai_India',
#  'Gradignan_Francia',
#  'Buffalo Grove_Estados Unidos',
#  'Xinzhou_China',
#  'Zhoukou_China',
#  'Belleville_Estados Unidos',
#  'Reading_Estados Unidos',
#  'Ashqelon_Israel',
#  'Ibb_Yemen',
#  'Cleveland_EE. UU.',
#  'Iringa_Tanzania',
#  'Meerut_India',
#  'Ekibastuz_Kazajistán',
#  'Sahuayo de José María Morelos_México',
#  'Clichy_Francia',
#  'Tumkur_India',
#  'Kinshasa_República Democrática del Congo',
#  'Silivri_Turquía',
#  'Huntington Beach_EE. UU.',
#  'Benidorm_España',
#  'Blacksburg_EE. UU.',
#  'Lublin_Polonia',
#  'Nagasaki_Japón',
#  'Nishinomiya_Japón',
#  'Lansing_Estados Unidos',
#  'Sabadell_España',
#  'Boa Vista_Brasil',
#  'Roseburg_EE. UU.',
#  'Columbus_Estados Unidos',
#  'Samsun_Turquía',
#  'Corrientes_Argentina',
#  'Handa_Japón',
#  'Siauliai_Lituania',
#  'Changsha_China',
#  'Fairfield_EE. UU.',
#  'Kaliningrado_Rusia',
#  'Santiago del Estero_Argentina',
#  'Gómel_Bielorrusia',
#  'Westminster_EE. UU.',
#  'Tamale_Ghana',
#  'Solna_Suecia',
#  'Gelsenkirchen_Alemania',
#  'Salina Cruz_México',
#  'Nampula_Mozambique',
#  'Georgetown_Estados Unidos',
#  'Jieshou_China',
#  'Marl_Alemania',
#  'Abeokuta_Nigeria',
#  'Ragusa_Italia',
#  'Tulare_EE. UU.',
#  'Duluth_EE. UU.',
#  'Apopa_El Salvador',
#  'Villa Canales_Guatemala',
#  'Santa Barbara_Estados Unidos',
#  'Oullins_Francia',
#  'Wyoming_EE. UU.',
#  'Jacareí_Brasil',
#  'Quito_Ecuador',
#  'Umraniye_Turquía',
#  'Miami_EE. UU.',
#  'Stafford_EE. UU.',
#  'Blumenau_Brasil',
#  'Leverkusen_Alemania',
#  "Nal'chik_Rusia",
#  'Lakeville_Estados Unidos',
#  'Westland_Estados Unidos',
#  'Palembang_Indonesia',
#  'Boulogne-Billancourt_Francia',
#  'Cuenca_España',
#  'Mâcon_Francia',
#  'Moorhead_Estados Unidos',
#  'Bad Waldsee_Alemania',
#  'Cape Town_SudAfrica',
#  'Santiago de Cuba_Cuba',
#  'Patrocínio_Brasil',
#  'Katoomba_Australia',
#  'Indaiatuba_Brasil',
#  'Montería_Colombia',
#  'Morgan Hill_Estados Unidos',
#  'Davis_EE. UU.',
#  'Rochdale_Reino Unido',
#  'Bento Gonçalves_Brasil',
#  'Elda_España',
#  'Villemomble_Francia',
#  'Orange_Estados Unidos',
#  'Roodepoort_SudAfrica',
#  'Ashford_Reino Unido',
#  'Bhatpara_India',
#  'Ennigerloh_Alemania',
#  'Bradford_Reino Unido',
#  'Encinitas_EE. UU.',
#  'Springdale_Estados Unidos',
#  'Yantai_China',
#  'Haifa_Israel',
#  'Mission Viejo_EE. UU.',
#  'South Bend_Estados Unidos',
#  'Sylmar_EE. UU.',
#  'Lowestoft_Reino Unido',
#  'Port Arthur_Estados Unidos',
#  'Shangzhi_China',
#  'Beaverton_EE. UU.',
#  'Christchurch_Nueva Zelanda',
#  'Saint Cloud_Estados Unidos',
#  'Kwinana_Australia',
#  'Cubuk_Turquía',
#  'Calais_Francia',
#  'Paraná_Argentina',
#  'Asiut_Egipto',
#  'Camaçari_Brasil',
#  'Cairns_Australia',
#  'Laredo_Estados Unidos',
#  'Apopka_Estados Unidos',
#  'Westonaria_SudAfrica',
#  'La Paz_México',
#  'New Brunswick_Estados Unidos',
#  'Albuquerque_EE. UU.',
#  'Wasquehal_Francia',
#  'Oberhausen_Alemania',
#  'Teziutlán_México',
#  'Neuilly-sur-Marne_Francia',
#  'Angers_Francia',
#  'Grasse_Francia',
#  'Allauch_Francia',
#  'Norwalk_EE. UU.',
#  'Liuyang_China',
#  "Be'er Sheva_Israel",
#  'Yakarta_Indonesia',
#  'Altamira_Brasil',
#  'Alhambra_EE. UU.',
#  'Kakinada_India',
#  'Juana Diaz_Puerto Rico',
#  'Rohtak_India',
#  'San Severo_Italia',
#  'Jizzakh_Uzbekistán',
#  'Olathe_EE. UU.',
#  'Alexandria_Egipto',
#  'Newcastle_SudAfrica',
#  'Hyderabad_Pakistán',
#  'Dole_Francia',
#  'West Chester_EE. UU.',
#  'Kukatpalli_India',
#  'San Sebastian_Puerto Rico',
#  'Crawley_Reino Unido',
#  'Antioch_EE. UU.',
#  'San Pedro_EE. UU.',
#  'Revere_Estados Unidos',
#  'Osny_Francia',
#  'Jamnagar_India',
#  'Tianjin_China',
#  'Martigues_Francia',
#  'Villeurbanne_Francia',
#  'Hemel Hempstead_Reino Unido',
#  'Gravataí_Brasil',
#  'Takasaki_Japón',
#  'Woonsocket_Estados Unidos',
#  'Torbali_Turquía',
#  'Tuscaloosa_Estados Unidos',
#  'Yuncheng_China',
#  'Tahta_Egipto',
#  'Usak_Turquía',
#  'Buriticupu_Brasil',
#  'Aachen_Alemania',
#  'Yogyakarta_Indonesia',
#  'Linhares_Brasil',
#  'Pistoia_Italia',
#  'Rybnik_Polonia',
#  'Kerman_Irán',
#  'Saint-Laurent-du-Var_Francia',
#  'Gubkin_Rusia',
#  'Sartrouville_Francia',
#  'Loudi_China',
#  'Kars_Turquía',
#  'Takamatsu_Japón',
#  'New Plymouth_Nueva Zelanda',
#  'Bottrop_Alemania',
#  'Tieling_China',
#  'Targu Jiu_Rumania',
#  'Valencia_Filipinas',
#  'Mosquera_Colombia',
#  'Legnano_Italia',
#  'Bhilwara_India',
#  'Hadera_Israel',
#  'Gombe_Nigeria',
#  'Tel Aviv_Israel',
#  'Bremerhaven_Alemania',
#  'Manaus_Brasil',
#  'Nanchong_China',
#  'Bezons_Francia',
#  'Surakarta_Indonesia',
#  'Pontivy_Francia',
#  'Chatou_Francia',
#  'New Albany_Estados Unidos',
#  'Mulhouse_Francia',
#  'Valdemoro_España',
#  'San Pablo de las Salinas_México',
#  'Manresa_España',
#  'Whitby_Canada',
#  'Gebze_Turquía',
#  'Escondido_Estados Unidos',
#  'Chengdu_China',
#  'Pasadena_EE. UU.',
#  'Southend-on-Sea_Reino Unido',
#  'Ercolano_Italia',
#  'Astracán_Rusia',
#  'Bareilly_India',
#  'Soweto_SudAfrica',
#  'Sukabumi_Indonesia',
#  'Troyes_Francia',
#  'Polatli_Turquía',
#  'Plaisir_Francia',
#  'Nysa_Polonia',
#  'Montigny-le-Bretonneux_Francia',
#  'Corum_Turquía',
#  'Quincy_Estados Unidos',
#  'Viransehir_Turquía',
#  'Clovis_Estados Unidos',
#  'San Luis_Argentina',
#  'Yopal_Colombia',
#  'Lower Hutt_Nueva Zelanda',
#  'El Jadida_Marruecos',
#  'Akola_India',
#  'Huaibei_China',
#  'Bozeman_Estados Unidos',
#  'Herford_Alemania',
#  'Wheeling_EE. UU.',
#  'Dartford_Reino Unido',
#  'Ruda Slaska_Polonia',
#  'Trappes_Francia',
#  'Caucaia_Brasil',
#  ...}

# %%
# Create a dictionary to map node identifiers to node IDs
node_to_id = {node: i for i, node in enumerate(nodes)}

from collections import defaultdict
# Initialize an adjacency list for the graph
graph = defaultdict(set)

# Create edges between nodes
for index, raw_in in df.iterrows():
    start_node = raw_in["start_node"]
    end_node = raw_in["end_node"]
    graph[node_to_id[start_node]].add(node_to_id[end_node])
    graph[node_to_id[end_node]].add(node_to_id[start_node])

# %%
id_to_node = {i: node for i, node in enumerate(nodes)}

# %%
graph[node_to_id["Arbil_Irak"]]
# Out:
# {519,
#  798,
#  1127,
#  1330,
#  1355,
#  1507,
#  1545,
#  1572,
#  1625,
#  1879,
#  2148,
#  2406,
#  2526,
#  2726,
#  2937,
#  3367,
#  3403,
#  3869}

# %%
from collections import deque


def bfs(graph, start_node, end_node, num_paths=3):
    queue = deque([(start_node, [start_node], 0)])
    shortest_paths = []

    while queue:
        current_node, current_path, current_length = queue.popleft()

        if current_node == end_node:
            shortest_paths.append((current_path, current_length))
            if len(shortest_paths) == num_paths:
                break
            continue
        
        for neighbor in graph[current_node]:
            if neighbor in current_path:
                continue
            new_path = current_path + [neighbor]
            queue.append((neighbor, new_path, current_length + 1))

    return shortest_paths


# Perform BFS starting from a specific node
start_node = node_to_id["Venice_Italia"]
end_node = node_to_id["Arbil_Irak"]
routes = bfs(graph, start_node, end_node)
for route, path_len in routes:
    print(f"path length: {path_len}")
    for node in route:
        print(id_to_node[node])
    print("---------")
# Out:
# path length: 2
# Venice_Italia
# Caguas_Puerto Rico
# Arbil_Irak
# ---------
# path length: 2
# Venice_Italia
# Chicago_EE. UU.
# Arbil_Irak
# ---------
# path length: 2
# Venice_Italia
# Los Angeles_EE. UU.
# Arbil_Irak
# ---------

# %%
import joblib
joblib.dump(graph, "graph.pkl")
joblib.dump(node_to_id, "node2id.pkl")
joblib.dump(id_to_node, "id2node.pkl")
# Out:
# ['id2node.pkl']

# %%
import joblib
import torch
from SimpleNeuralNet import NeuralNetwork

graph = joblib.load("graph.pkl")
node_to_id = joblib.load("node2id.pkl")
id_to_node = joblib.load("id2node.pkl")
days_scaler = joblib.load("days_pred_scaler.pkl")
other_scaler = joblib.load("quantity_distance_scaler.pkl")
cost_scaler = joblib.load("cost_scaler.pkl")

origin_cities = joblib.load("Customer City.pkl")
origin_cities = {city: i for city, i in zip(origin_cities, range(len(origin_cities)))}
origin_countries = joblib.load("Customer Country.pkl")
origin_countries = {
    country: i for country, i in zip(origin_countries, range(len(origin_countries)))
}
destination_cities = joblib.load("Order City.pkl")
destination_cities = {
    city: i for city, i in zip(destination_cities, range(len(destination_cities)))
}
destination_countries = joblib.load("Order Country.pkl")
destination_countries = {
    country: i
    for country, i in zip(destination_countries, range(len(destination_countries)))
}
shipping_modes = {"Standard Class": 0, "First Class": 1, "Second Class": 2, "Same Day": 3}

days_model = NeuralNetwork(902, 64)
days_model.load_state_dict(torch.load("days_model.pth"))
days_model.eval()
# Out:
# NeuralNetwork(
#   (fc1): Linear(in_features=902, out_features=64, bias=True)
#   (dropout1): Dropout(p=0.15, inplace=False)
#   (fc2): Linear(in_features=64, out_features=16, bias=True)
#   (dropout2): Dropout(p=0.1, inplace=False)
#   (fc3): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
# quantity, category, origin city/country, destination city/country, mode
# raw_input = [1, 12, "Venice", "Italia", "Arbil", "Irak", "Standard Class"]
raw_input = [1, 12, "Venice", "Italia", "San Jose", "EE. UU.", "Standard Class"]

# calculate distance
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

geolocator = Nominatim(user_agent="city_distance_calculator")


def geocode_location(city, country):
    try:
        query = dict()
        query["city"] = city
        query["country"] = country
        location = geolocator.geocode(query, exactly_one=True)
        if location is None:
            return None
        return location
    except:
        return None


geo_origin = geocode_location(raw_input[2], raw_input[3])
geo_dest = geocode_location(raw_input[4], raw_input[5])

start_coords = (geo_origin.latitude, geo_origin.longitude)
end_coords = (geo_dest.latitude, geo_dest.longitude)
distance = geodesic(start_coords, end_coords).kilometers

# normalize quantity and distance
import pandas as pd

processed_input = (
    other_scaler.transform(
        pd.DataFrame({"Order Item Quantity": [raw_input[0]], "Distance": [distance]})
    )
    .flatten()
    .tolist()
)

# one hot
categories = [0] * 32
categories[raw_input[1] - 1] = 1
processed_input += categories

if raw_input[2] not in origin_cities or raw_input[3] not in origin_countries:
    raw_input[2:4], raw_input[4:6] = raw_input[4:6], raw_input[2:4]
temp = [0] * len(origin_cities)
temp[origin_cities[raw_input[2]]] = 1
processed_input += temp
temp = [0] * len(origin_countries)
temp[origin_countries[raw_input[3]]] = 1
processed_input += temp
temp = [0] * len(destination_cities)
temp[destination_cities[raw_input[4]]] = 1
processed_input += temp
temp = [0] * len(destination_countries)
temp[destination_countries[raw_input[5]]] = 1
processed_input += temp

temp = [0] * len(shipping_modes)
temp[shipping_modes[raw_input[-1]]] = 1
processed_input += temp

days_scaler.inverse_transform(
    days_model(torch.Tensor(processed_input)).detach().numpy().reshape(-1, 1)
)
# Out:
# array([[2.0976655]], dtype=float32)

# %%
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

geolocator = Nominatim(user_agent="city_distance_calculator")


def geocode_location(city, country):
    try:
        query = dict()
        query["city"] = city
        query["country"] = country
        location = geolocator.geocode(query, exactly_one=True)
        if location is None:
            return None
        return location
    except:
        return None

# %%
import pandas as pd

def preprocess_input(raw_input):
    geo_origin = geocode_location(raw_input[2], raw_input[3])
    geo_dest = geocode_location(raw_input[4], raw_input[5])

    if geo_origin is None or geo_dest is None:
        return None

    start_coords = (geo_origin.latitude, geo_origin.longitude)
    end_coords = (geo_dest.latitude, geo_dest.longitude)
    distance = geodesic(start_coords, end_coords).kilometers

    # normalize quantity and distance
    processed_input = (
        other_scaler.transform(
            pd.DataFrame({"Order Item Quantity": [raw_input[0]], "Distance": [distance]})
        )
        .flatten()
        .tolist()
    )

    # one hot
    categories = [0] * 32
    categories[raw_input[1] - 1] = 1
    processed_input += categories

    if raw_input[2] not in origin_cities or raw_input[3] not in origin_countries:
        raw_input[2:4], raw_input[4:6] = raw_input[4:6], raw_input[2:4]
    temp = [0] * len(origin_cities)
    temp[origin_cities[raw_input[2]]] = 1
    processed_input += temp
    temp = [0] * len(origin_countries)
    temp[origin_countries[raw_input[3]]] = 1
    processed_input += temp
    temp = [0] * len(destination_cities)
    temp[destination_cities[raw_input[4]]] = 1
    processed_input += temp
    temp = [0] * len(destination_countries)
    temp[destination_countries[raw_input[5]]] = 1
    processed_input += temp

    temp = [0] * len(shipping_modes)
    temp[shipping_modes[raw_input[-1]]] = 1
    processed_input += temp

    return processed_input

# %%
from collections import deque

def bfs(graph, start_node, end_node, num_paths=3):
    queue = deque([[start_node]])
    shortest_paths = []

    while queue:
        current_path = queue.popleft()
        current_node = current_path[-1]

        if current_node == end_node:
            shortest_paths.append(current_path)
            if len(shortest_paths) == num_paths:
                break
            continue
        
        for neighbor in graph[current_node]:
            if neighbor in current_path:
                continue
            new_path = current_path + [neighbor]
            queue.append((new_path))

    return shortest_paths

# %%
raw_input = [1, 12, "Venice", "Italia", "Florence", "Italia", "Standard Class"]

# Perform BFS starting from a specific node
start_node = node_to_id["_".join(raw_input[2:4])]
end_node = node_to_id["_".join(raw_input[4:6])]
routes = bfs(graph, start_node, end_node)
for route in routes:
    total_days = 0
    for i in range(len(route) - 1):
        print(f"{id_to_node[route[i]]} to {id_to_node[route[i + 1]]}")
        current_input = raw_input[0:2]
        current_input += id_to_node[route[i]].split("_")
        current_input += id_to_node[route[i + 1]].split("_")
        current_input += [raw_input[6]]
        processed_input = preprocess_input(current_input)
        if processed_input is None:
            print("location not found, skipping")
            break
        days = days_scaler.inverse_transform(
            days_model(torch.Tensor(processed_input)).detach().numpy().reshape(-1, 1)
        ).squeeze()
        total_days += days
        print(f"{days} days")
    print(f"total: {total_days} days")
    print("---------")
# Out:
# Venice_Italia to Dallas_EE. UU.
# 1.641310691833496 days
# Dallas_EE. UU. to Florence_Italia
# 1.2860562801361084 days
# total: 2.9273669719696045 days
# ---------
# Venice_Italia to Houston_EE. UU.
# 1.325096845626831 days
# Houston_EE. UU. to Florence_Italia
# 1.1243057250976562 days
# total: 2.4494025707244873 days
# ---------
# Venice_Italia to Caguas_Puerto Rico
# location not found, skipping
# total: 0 days
# ---------
