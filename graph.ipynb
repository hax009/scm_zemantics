# %%
import pandas as pd

df = pd.read_csv("DataCoSupplyChainDataset.csv", encoding="latin-1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
#  12  Customer Fname                 180519 non-null  object
#  13  Customer Id                    180519 non-null  int64
#  14  Customer Lname                 180511 non-null  object
#  15  Customer Password              180519 non-null  object
#  16  Customer Segment               180519 non-null  object
#  17  Customer State                 180519 non-null  object
#  18  Customer Street                180519 non-null  object
#  19  Customer Zipcode               180516 non-null  float64
#  20  Department Id                  180519 non-null  int64
#  21  Department Name                180519 non-null  object
#  22  Latitude                       180519 non-null  float64
#  23  Longitude                      180519 non-null  float64
#  24  Market                         180519 non-null  object
#  25  Order City                     180519 non-null  object
#  26  Order Country                  180519 non-null  object
#  27  Order Customer Id              180519 non-null  int64
#  28  order date (DateOrders)        180519 non-null  object
#  29  Order Id                       180519 non-null  int64
#  30  Order Item Cardprod Id         180519 non-null  int64
#  31  Order Item Discount            180519 non-null  float64
#  32  Order Item Discount Rate       180519 non-null  float64
#  33  Order Item Id                  180519 non-null  int64
#  34  Order Item Product Price       180519 non-null  float64
#  35  Order Item Profit Ratio        180519 non-null  float64
#  36  Order Item Quantity            180519 non-null  int64
#  37  Sales                          180519 non-null  float64
#  38  Order Item Total               180519 non-null  float64
#  39  Order Profit Per Order         180519 non-null  float64
#  40  Order Region                   180519 non-null  object
#  41  Order State                    180519 non-null  object
#  42  Order Status                   180519 non-null  object
#  43  Order Zipcode                  24840 non-null   float64
#  44  Product Card Id                180519 non-null  int64
#  45  Product Category Id            180519 non-null  int64
#  46  Product Description            0 non-null       float64
#  47  Product Image                  180519 non-null  object
#  48  Product Name                   180519 non-null  object
#  49  Product Price                  180519 non-null  float64
#  50  Product Status                 180519 non-null  int64
#  51  shipping date (DateOrders)     180519 non-null  object
#  52  Shipping Mode                  180519 non-null  object
# dtypes: float64(15), int64(14), object(24)
# memory usage: 73.0+ MB

# %%
df["start_node"] = df["Customer City"] + "_" + df["Customer Country"]
df["end_node"] = df["Order City"] + "_" + df["Order Country"]
nodes = set(df["start_node"].unique()).union(df["end_node"].unique())
nodes
# Out:
# {'Gujranwala_Pakistán',
#  'Cambridge_Reino Unido',
#  'Vineland_Estados Unidos',
#  'Solapur_India',
#  'San Cristóbal_Venezuela',
#  'Mantes-la-Ville_Francia',
#  'Chililabombwe_Zambia',
#  'Santa Fe_Estados Unidos',
#  'Oxnard_EE. UU.',
#  'Venice_Italia',
#  'Brentwood_EE. UU.',
#  'Arbil_Irak',
#  'Palma Soriano_Cuba',
#  'Blenheim_Nueva Zelanda',
#  'Kolhapur_India',
#  'Hillsboro_Estados Unidos',
#  'Rangún_Myanmar (Birmania)',
#  'Waterlooville_Reino Unido',
#  'Ponteareas_España',
#  'Bayamon_Puerto Rico',
#  'Warsaw_Polonia',
#  'Canton_EE. UU.',
#  'Tsukuba_Japón',
#  'São Gonçalo_Brasil',
#  'Vanves_Francia',
#  'Caracas_Venezuela',
#  'Elx_España',
#  'Kabwe_Zambia',
#  'Utica_Estados Unidos',
#  'Itapecerica da Serra_Brasil',
#  'Martinsburg_EE. UU.',
#  'La Crosse_Estados Unidos',
#  'Delft_Países Bajos',
#  'Botosani_Rumania',
#  'Taubaté_Brasil',
#  'Bondy_Francia',
#  'Jember_Indonesia',
#  'Bafra_Turquía',
#  'Forster_Australia',
#  'Yushu_China',
#  'Lianyuan_China',
#  'Frankfort_EE. UU.',
#  'Henrico_EE. UU.',
#  'Granada_Nicaragua',
#  'Saint-Gratien_Francia',
#  'Gulu_Uganda',
#  'Salinas_EE. UU.',
#  'Yalova_Turquía',
#  'Eragny_Francia',
#  'Ulm_Alemania',
#  'Colton_EE. UU.',
#  'Laguna Hills_EE. UU.',
#  'Chinautla_Guatemala',
#  'Martinez_EE. UU.',
#  'Nellore_India',
#  'Maringá_Brasil',
#  "Cournon-d'Auvergne_Francia",
#  'Mubi_Nigeria',
#  'Kollam_India',
#  'Zhenjiang_China',
#  'Wuxi_China',
#  'Yuma_Estados Unidos',
#  'Itamaraju_Brasil',
#  'Tamworth_Reino Unido',
#  'Saanich_Canada',
#  'Oosterhout_Países Bajos',
#  'Moradabad_India',
#  'Corona_EE. UU.',
#  'Hoover_Estados Unidos',
#  'Round Rock_EE. UU.',
#  'Tanta_Egipto',
#  'Amagasaki_Japón',
#  'Norcross_EE. UU.',
#  'Winnetka_EE. UU.',
#  'Khouribga_Marruecos',
#  'Meknes_Marruecos',
#  'Creil_Francia',
#  'Gela_Italia',
#  'Lynwood_EE. UU.',
#  'Depok_Indonesia',
#  'Mangalore_India',
#  'Rochester_Estados Unidos',
#  'Siirt_Turquía',
#  'Rialto_EE. UU.',
#  'Porirua_Nueva Zelanda',
#  'Grove City_EE. UU.',
#  'Bochum_Alemania',
#  'Radom_Polonia',
#  'Upplands Väsby_Suecia',
#  'Athens_Grecia',
#  'Braga_Portugal',
#  'Quito_Ecuador',
#  'Wuppertal_Alemania',
#  'Qom_Irán',
#  'Halifax_Reino Unido',
#  'Lida_Bielorrusia',
#  'Trappes_Francia',
#  'Xiantao_China',
#  'General Escobedo_México',
#  'Palo Negro_Venezuela',
#  'Geelong_Australia',
#  'Maltepe_Turquía',
#  'Ancona_Italia',
#  'Jingmen_China',
#  'Onitsha_Nigeria',
#  'Parker_Estados Unidos',
#  'Guildford_Reino Unido',
#  'Rennes_Francia',
#  "Quartu Sant'Elena_Italia",
#  'Rillieux-la-Pape_Francia',
#  'Holyoke_Estados Unidos',
#  'Arapiraca_Brasil',
#  'Chaozhou_China',
#  'Rueil-Malmaison_Francia',
#  'Ipswich_Reino Unido',
#  'Ipatinga_Brasil',
#  'Domont_Francia',
#  'Durg_India',
#  'Le Petit-Quevilly_Francia',
#  'Regensburg_Alemania',
#  'Sabzevar_Irán',
#  'Rasht_Irán',
#  'Lincoln Park_Estados Unidos',
#  'Memphis_EE. UU.',
#  'Katowice_Polonia',
#  'North Richland Hills_EE. UU.',
#  'Normal_EE. UU.',
#  'Bihar Sharif_India',
#  'Palembang_Indonesia',
#  'Zhongxiang_China',
#  'Kindu_República Democrática del Congo',
#  'La Paz_Bolivia',
#  'Campina Grande_Brasil',
#  'Tallahassee_Estados Unidos',
#  'Duluth_EE. UU.',
#  'Randfontein_SudAfrica',
#  'Zhuhai_China',
#  'Yuma_EE. UU.',
#  'Limoeiro do Norte_Brasil',
#  'Milpitas_EE. UU.',
#  'El Monte_EE. UU.',
#  'Changzhi_China',
#  'Guayaquil_Ecuador',
#  'Craiova_Rumania',
#  'Tulare_EE. UU.',
#  'Bremerhaven_Alemania',
#  'Colchester_Reino Unido',
#  'Lodz_Polonia',
#  'Inglewood_Estados Unidos',
#  'Pingnan_China',
#  'Hayange_Francia',
#  'Bayonne_Estados Unidos',
#  'Korhogo_Costa de Marfil',
#  'Xuzhou_China',
#  'Passo Fundo_Brasil',
#  'Manacapuru_Brasil',
#  'Polatsk_Bielorrusia',
#  'Montes Claros_Brasil',
#  'Gravataí_Brasil',
#  'Guangzhou_China',
#  'Enfield_EE. UU.',
#  'Mbeya_Tanzania',
#  'Iskenderun_Turquía',
#  'Carmichael_EE. UU.',
#  'El Ejido_España',
#  'Anyang_Corea del Sur',
#  'Sarreguemines_Francia',
#  'Barranquilla_Colombia',
#  'Shinyanga_Tanzania',
#  'Hamar_Noruega',
#  'Noda_Japón',
#  'Las Cruces_Estados Unidos',
#  'Ludwigsburg_Alemania',
#  'Surakarta_Indonesia',
#  'Landerneau_Francia',
#  'Marsa Matruh_Egipto',
#  'Rockford_Estados Unidos',
#  'Cajazeiras_Brasil',
#  'Presidente Prudente_Brasil',
#  'Villach_Austria',
#  'Nantes_Francia',
#  'Dar es Salaam_Tanzania',
#  'Milford_EE. UU.',
#  'Luanshya_Zambia',
#  'Focsani_Rumania',
#  'Yao_Japón',
#  'Liberec_República Checa',
#  'West Haven_EE. UU.',
#  'Yibuti_Yibuti',
#  'Yicheng_China',
#  'Cabo de Santo Agostinho_Brasil',
#  'Roubaix_Francia',
#  'Bayeux_Brasil',
#  'Sunnyvale_EE. UU.',
#  'Borazjan_Irán',
#  "Villenave-d'Ornon_Francia",
#  'Shimoga_India',
#  'Cassilândia_Brasil',
#  'San Cristóbal de Las Casas_México',
#  'Cajamarca_Perú',
#  'Al Hillah_Irak',
#  'Kuala Terengganu_Malasia',
#  'Palm Coast_Estados Unidos',
#  'La Crosse_EE. UU.',
#  'Cologne_Alemania',
#  'San Bernardino_Estados Unidos',
#  'Saint-Jean-de-la-Ruelle_Francia',
#  'Benidorm_España',
#  'Waukegan_EE. UU.',
#  'Adiyaman_Turquía',
#  'Getafe_España',
#  'Cottage Grove_Estados Unidos',
#  'Sartrouville_Francia',
#  'Mougins_Francia',
#  'Navegantes_Brasil',
#  'Kenner_Estados Unidos',
#  'Burgas_Bulgaria',
#  'Khomeynishahr_Irán',
#  'New Plymouth_Nueva Zelanda',
#  'Tempe_Estados Unidos',
#  'Lens_Francia',
#  'Gisborne_Nueva Zelanda',
#  'Pierrefitte-sur-Seine_Francia',
#  'Cairo_Egipto',
#  'Charleroi_Bélgica',
#  'Abha_Arabia Saudí',
#  'Palencia_España',
#  'Colorado Springs_Estados Unidos',
#  'Ranchi_India',
#  'Sonsonate_El Salvador',
#  'Silivri_Turquía',
#  'Bolton_Reino Unido',
#  'Kirsehir_Turquía',
#  'Registro_Brasil',
#  'Pematangsiantar_Indonesia',
#  'Brownsville_EE. UU.',
#  'Sannois_Francia',
#  'Anyang_China',
#  'Thousand Oaks_Estados Unidos',
#  'The Hague_Países Bajos',
#  'Jiangyan_China',
#  'Munster_Alemania',
#  'Simões Filho_Brasil',
#  'Ninghai_China',
#  'Dortmund_Alemania',
#  'Qarshi_Uzbekistán',
#  'Jiaozuo_China',
#  'York_Reino Unido',
#  'Castanhal_Brasil',
#  'Cayey_Puerto Rico',
#  'Calais_Francia',
#  'Mesquite_EE. UU.',
#  'Longjumeau_Francia',
#  'Stockton-on-Tees_Reino Unido',
#  'Mérida_Venezuela',
#  'Cuenca_Ecuador',
#  'Long Beach_Estados Unidos',
#  'Loures_Portugal',
#  'Dallas_Estados Unidos',
#  'Maceió_Brasil',
#  'Hermosillo_México',
#  'Iquitos_Perú',
#  'Bad Waldsee_Alemania',
#  'Park Ridge_Estados Unidos',
#  'Hilden_Alemania',
#  'Mopti_Mali',
#  'Derbent_Rusia',
#  'Béchar_Argelia',
#  'Chattanooga_Estados Unidos',
#  'Aba_Nigeria',
#  'Braila_Rumania',
#  'Karlsruhe_Alemania',
#  'Cayenne_Guayana Francesa',
#  'Poole_Reino Unido',
#  'Uithoorn_Países Bajos',
#  'Lakeville_Estados Unidos',
#  'Fianarantsoa_Madagascar',
#  'Hautmont_Francia',
#  'Mitry-Mory_Francia',
#  'Dabrowa Gornicza_Polonia',
#  'Resita_Rumania',
#  'Katy_EE. UU.',
#  'Aew?l-li_Corea del Sur',
#  'Brumado_Brasil',
#  'Aurora_EE. UU.',
#  'Rio Branco_Brasil',
#  'Uman_Ucrania',
#  'Sarcelles_Francia',
#  'Daytona Beach_Estados Unidos',
#  'Barakaldo_España',
#  'Peoria_Estados Unidos',
#  'Levallois-Perret_Francia',
#  'Avion_Francia',
#  'Karimnagar_India',
#  'Rabat_Marruecos',
#  'Zielona Gora_Polonia',
#  'Bratsk_Rusia',
#  'Salvador_Brasil',
#  'Vilna_Lituania',
#  'Plaisance-du-Touch_Francia',
#  'Birigui_Brasil',
#  'Eskilstuna_Suecia',
#  'Kathmandu_Nepal',
#  'Francisco Beltrão_Brasil',
#  'Upsala_Suecia',
#  'Tremblay-en-France_Francia',
#  'Gorakhpur_India',
#  'Kadoma_Zimbabue',
#  'Bari_Italia',
#  'Assen_Países Bajos',
#  'Treviglio_Italia',
#  'Tongzhou_China',
#  'Harbin_China',
#  'Hidalgo_México',
#  'Cainta_Filipinas',
#  'Can Tho_Vietnam',
#  'Palma de Mallorca_España',
#  'Warner Robins_Estados Unidos',
#  'Likasi_República Democrática del Congo',
#  'Tianguá_Brasil',
#  'Les Ulis_Francia',
#  'Gombe_Nigeria',
#  'Kawagoe_Japón',
#  'Contagem_Brasil',
#  'Chemnitz_Alemania',
#  'Opole_Polonia',
#  'Sobral_Brasil',
#  'Hohhot_China',
#  'Costa Mesa_EE. UU.',
#  'Salon-de-Provence_Francia',
#  'Atsugacho_Japón',
#  'Guatemala City_Guatemala',
#  'Yaritagua_Venezuela',
#  'Dinslaken_Alemania',
#  'San Miguelito_Panamá',
#  'Vanadzor_Armenia',
#  'Ginebra_Suiza',
#  'Hilliard_EE. UU.',
#  'Masterton_Nueva Zelanda',
#  'Nizhyn_Ucrania',
#  'Tigard_Estados Unidos',
#  'Hradec Králové_República Checa',
#  'Gandia_España',
#  'Athens_Estados Unidos',
#  'Oxnard_Estados Unidos',
#  'Stockton_EE. UU.',
#  'Split_Croacia',
#  'Ibb_Yemen',
#  'Herten_Alemania',
#  'Bayonne_Francia',
#  'Bisáu_Guinea-Bissau',
#  'Holland_EE. UU.',
#  'Santander_España',
#  'Kissimmee_Estados Unidos',
#  'Paramaribo_Surinam',
#  'San Nicolás de los Arroyos_Argentina',
#  'Neyshabur_Irán',
#  'Catia La Mar_Venezuela',
#  'Ponce_Puerto Rico',
#  'Pekín_China',
#  'Bajos de Haina_República Dominicana',
#  'Columbia_EE. UU.',
#  'Cuernavaca_México',
#  'Waipahu_EE. UU.',
#  'Bur Sudan_Sudán',
#  'Jiangmen_China',
#  'Aswan_Egipto',
#  'Chatou_Francia',
#  'Kamarhati_India',
#  'Stains_Francia',
#  'Chartres_Francia',
#  'Modena_Italia',
#  'New Haven_EE. UU.',
#  'Manchester_Reino Unido',
#  'León_Nicaragua',
#  'Haikou_China',
#  'Langenhagen_Alemania',
#  'Vitoria_España',
#  'Siedlce_Polonia',
#  'Genoa_Italia',
#  'Dorchester Center_EE. UU.',
#  'Mont-de-Marsan_Francia',
#  'Trujillo Alto_Puerto Rico',
#  'Apeldoorn_Países Bajos',
#  'Zhumadian_China',
#  'Tuzla_Bosnia y Herzegovina',
#  'Ashford_Reino Unido',
#  'Dire Dawa_Etiopía',
#  'Pembroke Pines_Estados Unidos',
#  'Chisináu_Moldavia',
#  'Neuilly-Plaisance_Francia',
#  'Lusaka_Zambia',
#  'Kailua_EE. UU.',
#  'Harrow_Reino Unido',
#  'Rambouillet_Francia',
#  'Canberra_Australia',
#  'Cizre_Turquía',
#  'Guelma_Argelia',
#  'Botshabelo_SudAfrica',
#  'Puteaux_Francia',
#  'Everett_Estados Unidos',
#  'Umtata_SudAfrica',
#  'Guayama_Puerto Rico',
#  'Bielefeld_Alemania',
#  'Le Mans_Francia',
#  'Cambridge_Nueva Zelanda',
#  'Sakai_Japón',
#  'Kawasaki_Japón',
#  'Jinhua_China',
#  'Ibirité_Brasil',
#  'Elkhart_Estados Unidos',
#  'Firozabad_India',
#  'Santana de Parnaíba_Brasil',
#  'Borujerd_Irán',
#  'Harare_Zimbabue',
#  'Wagga Wagga_Australia',
#  'Wheaton_EE. UU.',
#  'Bronx_EE. UU.',
#  'Madison_Estados Unidos',
#  'Vicenza_Italia',
#  'El Progreso_Honduras',
#  'Geraldton_Australia',
#  'Roseville_Estados Unidos',
#  'Linhares_Brasil',
#  'Montceau-les-Mines_Francia',
#  'Mysore_India',
#  'Barbacena_Brasil',
#  'Sanming_China',
#  'Kirkwood_Estados Unidos',
#  'Gloucester_Reino Unido',
#  'Daca_Bangladés',
#  'Chillán_Chile',
#  'Changzhou_China',
#  'Slough_Reino Unido',
#  'Posadas_Argentina',
#  'Mons-en-Baroeul_Francia',
#  'Sincan_Turquía',
#  'Renqiu_China',
#  'Surubim_Brasil',
#  'Malakoff_Francia',
#  'Penglai_China',
#  'Chiclana de la Frontera_España',
#  'Salem_India',
#  'Varese_Italia',
#  'Pescara_Italia',
#  'Neiva_Colombia',
#  'Lormont_Francia',
#  'Sanandaj_Irán',
#  'Concord_Estados Unidos',
#  'Los Patios_Colombia',
#  'Jersón_Ucrania',
#  'Renton_Estados Unidos',
#  'Sonipat_India',
#  'Puerto La Cruz_Venezuela',
#  'Jena_Alemania',
#  'Norwich_Estados Unidos',
#  'Indaiatuba_Brasil',
#  'Ploemeur_Francia',
#  'Ypsilanti_EE. UU.',
#  'Trujillo_Perú',
#  'Neuwied_Alemania',
#  'Oregon City_EE. UU.',
#  'Tartagal_Argentina',
#  'Dos Quebradas_Colombia',
#  'Staten Island_EE. UU.',
#  'Cotonou_Benín',
#  'Facatativá_Colombia',
#  'Mérida_México',
#  'Maidenhead_Reino Unido',
#  'Spring Valley_EE. UU.',
#  'Livingstone_Zambia',
#  'CA_EE. UU.',
#  'Pontault-Combault_Francia',
#  'Bogotá_Colombia',
#  'Meyzieu_Francia',
#  'Jiaohe_China',
#  'Fontana_EE. UU.',
#  'Resende_Brasil',
#  'Houilles_Francia',
#  'Capua_Italia',
#  'New Orleans_EE. UU.',
#  'Saint Louis_Estados Unidos',
#  "Luts'k_Ucrania",
#  'San Diego_EE. UU.',
#  'South El Monte_EE. UU.',
#  'Chifeng_China',
#  'East Orange_Estados Unidos',
#  'Tyler_Estados Unidos',
#  'Hialeah_Estados Unidos',
#  'Beverly_Estados Unidos',
#  'Monrovia_Liberia',
#  'Uvira_República Democrática del Congo',
#  'Abidjan_Costa de Marfil',
#  'La Plata_Argentina',
#  'Himeji_Japón',
#  'Kasama_Zambia',
#  'Union City_EE. UU.',
#  'La Chorrera_Panamá',
#  'Grand Island_Estados Unidos',
#  'Bikaner_India',
#  'Serra_Brasil',
#  'West Jordan_Estados Unidos',
#  'Pantin_Francia',
#  'Zaoyang_China',
#  'Takamatsu_Japón',
#  'Ploiesti_Rumania',
#  'Columbus_Estados Unidos',
#  'Santa Marta_Colombia',
#  'Uruguaiana_Brasil',
#  'Rochdale_Reino Unido',
#  'La Mesa_Estados Unidos',
#  'Bagé_Brasil',
#  'Wetzlar_Alemania',
#  'Southampton_Reino Unido',
#  'Vernon_Francia',
#  'Sacramento_Estados Unidos',
#  'San Antonio_EE. UU.',
#  'Toronto_Canada',
#  'Bellingham_EE. UU.',
#  'Chesapeake_EE. UU.',
#  'Franconville_Francia',
#  'Lake Charles_Estados Unidos',
#  'Xianyang_China',
#  'Carrara_Italia',
#  'Douglasville_EE. UU.',
#  'Boghni_Argelia',
#  'Richmond_Estados Unidos',
#  'Texarkana_Estados Unidos',
#  'Pertuis_Francia',
#  'Masaya_Nicaragua',
#  'Traralgon_Australia',
#  'Singapur_Singapur',
#  'Teherán_Irán',
#  'Hendersonville_EE. UU.',
#  'Birjand_Irán',
#  'Sandusky_EE. UU.',
#  'Tuxtla Gutiérrez_México',
#  'Twin Falls_Estados Unidos',
#  'Endicott_EE. UU.',
#  'Paramount_EE. UU.',
#  'Antiguo Cuscatlán_El Salvador',
#  'Jacobina_Brasil',
#  'Xiamen_China',
#  'Valladolid_España',
#  'Hove_Reino Unido',
#  'Amersfoort_Países Bajos',
#  'Dakar_Senegal',
#  'Avignon_Francia',
#  'Asheville_Estados Unidos',
#  'Kure_Japón',
#  'Molfetta_Italia',
#  'Viersen_Alemania',
#  'Sète_Francia',
#  'Vila Nova de Gaia_Portugal',
#  'Constanza_Rumania',
#  'Tamale_Ghana',
#  'Burnaby_Canada',
#  'Suining_China',
#  'Jastrzebie Zdroj_Polonia',
#  'Nampula_Mozambique',
#  'Aligudarz_Irán',
#  'San Luis_Argentina',
#  'Asti_Italia',
#  'Chaumont_Francia',
#  'Chorzow_Polonia',
#  'Boksburg_SudAfrica',
#  'Mililani_EE. UU.',
#  'Trenton_Estados Unidos',
#  'Vadodara_India',
#  'Panorama City_EE. UU.',
#  'Offenbach_Alemania',
#  'Leeuwarden_Países Bajos',
#  'Longview_Estados Unidos',
#  'Kunming_China',
#  'Palmira_Colombia',
#  "Nal'chik_Rusia",
#  'Danbury_EE. UU.',
#  'Barcelona_España',
#  'Tallahassee_EE. UU.',
#  'Frisco_Estados Unidos',
#  'Manila_Filipinas',
#  'Saida_Argelia',
#  'Nysa_Polonia',
#  'Huangshi_China',
#  'Saga_Japón',
#  'Frankfurt_Alemania',
#  'Behbahan_Irán',
#  'Nanchong_China',
#  'Safi_Marruecos',
#  'Fullerton_EE. UU.',
#  'New Albany_EE. UU.',
#  'Kalyan_India',
#  'Cesena_Italia',
#  'Jiutepec_México',
#  'Wilson_Estados Unidos',
#  'Gillingham_Reino Unido',
#  'Vincennes_Francia',
#  'Cruzeiro_Brasil',
#  'Lancaster_EE. UU.',
#  'Vitória da Conquista_Brasil',
#  'Cangzhou_China',
#  'Bergen op Zoom_Países Bajos',
#  'Indore_India',
#  'Forst_Alemania',
#  'Diamond Bar_EE. UU.',
#  'Osorno_Chile',
#  'Koumra_Chad',
#  'Poissy_Francia',
#  'Vijayawada_India',
#  'Karaman_Turquía',
#  'Aligarh_India',
#  'Grasse_Francia',
#  'Damanhur_Egipto',
#  'Boa Esperança_Brasil',
#  'Coimbra_Portugal',
#  'Rustenburg_SudAfrica',
#  'Aracati_Brasil',
#  'Villiers-sur-Marne_Francia',
#  'Shah Alam_Malasia',
#  'Maryborough_Australia',
#  'Fresno_Estados Unidos',
#  'Costa Mesa_Estados Unidos',
#  'Keren_Eritrea',
#  'Villa Canales_Guatemala',
#  'Limay_Francia',
#  'Lahore_Pakistán',
#  'Luohe_China',
#  'Parakou_Benín',
#  'Huixquilucan_México',
#  'Les Mureaux_Francia',
#  'Friedrichshafen_Alemania',
#  'Lawton_Estados Unidos',
#  'Round Rock_Estados Unidos',
#  'Hagen_Alemania',
#  'Poway_EE. UU.',
#  'Portici_Italia',
#  'Villeneuve-sur-Lot_Francia',
#  'Tivoli_Italia',
#  'Hickory_EE. UU.',
#  'Apple Valley_Estados Unidos',
#  'Marsabit_Kenia',
#  'Gummersbach_Alemania',
#  'Gateshead_Reino Unido',
#  'Saint-Michel-sur-Orge_Francia',
#  'Aachen_Alemania',
#  'Everett_EE. UU.',
#  'Wels_Austria',
#  'Greifswald_Alemania',
#  'Las Piedras_Uruguay',
#  'Salamanca_México',
#  'Broomfield_Estados Unidos',
#  'Cadereyta_México',
#  'Saint-Herblain_Francia',
#  'Armenia_Colombia',
#  'Tucson_Estados Unidos',
#  'Herat_Afganistán',
#  'Podgorica_Montenegro',
#  'Mansfield_Estados Unidos',
#  'Clacton-on-Sea_Reino Unido',
#  'Bellingham_Estados Unidos',
#  'Florissant_EE. UU.',
#  'Stellenbosch_SudAfrica',
#  'Fond Du Lac_EE. UU.',
#  'Bradford_Reino Unido',
#  'Houston_Estados Unidos',
#  'Paraná_Argentina',
#  'Zurich_Suiza',
#  'San Fernando_Trinidad y Tobago',
#  'Nazilli_Turquía',
#  'Cuscatancingo_El Salvador',
#  'Delgado_El Salvador',
#  'Morristown_Estados Unidos',
#  'San Fernando del Valle de Catamarca_Argentina',
#  'Coatzacoalcos_México',
#  'Outreau_Francia',
#  'Vaughan_Canada',
#  'Burbank_Estados Unidos',
#  'Kirovohrad_Ucrania',
#  'Funtua_Nigeria',
#  'Woodstock_Estados Unidos',
#  'Huaibei_China',
#  'Glendale_Estados Unidos',
#  'Naihati_India',
#  'Samarra_Irak',
#  'Erlangen_Alemania',
#  'Kumba_Camerún',
#  'Envigado_Colombia',
#  'Frederiksberg_Dinamarca',
#  'Chelles_Francia',
#  'Usak_Turquía',
#  'Folsom_EE. UU.',
#  'Brockton_EE. UU.',
#  'Chennai_India',
#  'Mission_EE. UU.',
#  'Bandar Abbas_Irán',
#  'Oldham_Reino Unido',
#  'Munich_Alemania',
#  'Bangor_Estados Unidos',
#  'Whangarei_Nueva Zelanda',
#  'Edea_Camerún',
#  'Anglet_Francia',
#  'Calgary_Canada',
#  'Sterlitamak_Rusia',
#  'Bucaramanga_Colombia',
#  'Chesterfield_Reino Unido',
#  'Ilopango_El Salvador',
#  'Calabozo_Venezuela',
#  'Uvinza_Tanzania',
#  'Araranguá_Brasil',
#  'Nagpur_India',
#  'Modesto_Estados Unidos',
#  'Pavlodar_Kazajistán',
#  'Morogoro_Tanzania',
#  'Jambi_Indonesia',
#  'Uskudar_Turquía',
#  'Gongzhuling_China',
#  'Antony_Francia',
#  'Batna_Argelia',
#  'Wendeng_China',
#  'Toamasina_Madagascar',
#  'Kahramanmara?_Turquía',
#  'West Jordan_EE. UU.',
#  'Lindenhurst_Estados Unidos',
#  'Nova Serrana_Brasil',
#  'Huntsville_Estados Unidos',
#  'Diadema_Brasil',
#  'Nairobi_Kenia',
#  'Yunyang_China',
#  'San José de las Lajas_Cuba',
#  'Sorgues_Francia',
#  'Montereau-Fault-Yonne_Francia',
#  'Cleveland_EE. UU.',
#  'Mumbai_India',
#  'Bijie_China',
#  'Canyon Country_EE. UU.',
#  'Ekibastuz_Kazajistán',
#  'Miguel Hidalgo_México',
#  'Rheine_Alemania',
#  'Chimoio_Mozambique',
#  'Darton_Reino Unido',
#  'Vassouras_Brasil',
#  'Tampico_México',
#  'Zhengzhou_China',
#  'Anápolis_Brasil',
#  'Waiblingen_Alemania',
#  'Minneapolis_Estados Unidos',
#  'Orihuela_España',
#  'Johnson City_Estados Unidos',
#  'Fresno_EE. UU.',
#  'Gastonia_Estados Unidos',
#  'Carvin_Francia',
#  'Quevedo_Ecuador',
#  'Chillicothe_EE. UU.',
#  'Francisco Morato_Brasil',
#  'Viena_Austria',
#  'Kaliningrado_Rusia',
#  'Damaturu_Nigeria',
#  'Lanester_Francia',
#  'Kerman_Irán',
#  'Coulommiers_Francia',
#  'Mwanza_Tanzania',
#  'Mascate_Omán',
#  'Newcastle upon Tyne_Reino Unido',
#  'Grove City_Estados Unidos',
#  'Sapucaia do Sul_Brasil',
#  'Marietta_Estados Unidos',
#  'Vallauris_Francia',
#  'Pamiers_Francia',
#  'Granada Hills_EE. UU.',
#  'Sydney_Australia',
#  'Fort Collins_Estados Unidos',
#  'Le Creusot_Francia',
#  'Bunbury_Australia',
#  'Oceanside_Estados Unidos',
#  'Salzburgo_Austria',
#  'Southaven_Estados Unidos',
#  'Sanary-sur-Mer_Francia',
#  'Neuilly-sur-Seine_Francia',
#  'Bhavnagar_India',
#  'Mechelen_Bélgica',
#  'Kerpen_Alemania',
#  'Hanover_EE. UU.',
#  'Bracknell_Reino Unido',
#  'Lakewood_EE. UU.',
#  'Riberalta_Bolivia',
#  'Roeselare_Bélgica',
#  'Huadian_China',
#  'Westerville_EE. UU.',
#  'Saint Charles_EE. UU.',
#  'Sucre_Bolivia',
#  'Raleigh_EE. UU.',
#  'Maracaibo_Venezuela',
#  'Edinburg_EE. UU.',
#  'Elbeuf_Francia',
#  'Khemisset_Marruecos',
#  'Ruda Slaska_Polonia',
#  'Fano_Italia',
#  'Casablanca_Marruecos',
#  'Baltimore_EE. UU.',
#  'Rhondda_Reino Unido',
#  'Natal_Brasil',
#  'Hamilton_EE. UU.',
#  'Goiânia_Brasil',
#  'Marion_Estados Unidos',
#  'Xianning_China',
#  'Belleville_Estados Unidos',
#  'Badajoz_España',
#  'Thomasville_Estados Unidos',
#  'Erechim_Brasil',
#  'Jinan_China',
#  'Bo_Sierra Leona',
#  'Yauco_Puerto Rico',
#  'Vista_EE. UU.',
#  'New York City_Estados Unidos',
#  'Varanasi_India',
#  'Jamnagar_India',
#  'Medina_Arabia Saudí',
#  'Upper Hutt_Nueva Zelanda',
#  'Hengyang_China',
#  'Juárez_México',
#  'Crown Point_EE. UU.',
#  'Ardahan_Turquía',
#  'Pemba_Mozambique',
#  'Catanduva_Brasil',
#  'Cabo Frio_Brasil',
#  'Iguala_México',
#  'Guaratinguetá_Brasil',
#  'Rosenheim_Alemania',
#  'Montecatini Terme_Italia',
#  'Mexico City_México',
#  'Providence_Estados Unidos',
#  'Murray_Estados Unidos',
#  'Watertown_Estados Unidos',
#  'Carson_EE. UU.',
#  'Lompoc_EE. UU.',
#  'Acuña_México',
#  'Pelotas_Brasil',
#  'Garden City_Estados Unidos',
#  'Matagalpa_Nicaragua',
#  'Gaborone_Botsuana',
#  'Nuneaton_Reino Unido',
#  'Baldwin Park_EE. UU.',
#  'Lome_Togo',
#  'Wuhai_China',
#  'Saint-Cloud_Francia',
#  'Burlington_Canada',
#  'Feira de Santana_Brasil',
#  'Gold Coast_Australia',
#  'Berlín_Alemania',
#  'Berwyn_EE. UU.',
#  'Arvada_Estados Unidos',
#  'Barcelona_Venezuela',
#  'Newport News_Estados Unidos',
#  'Makeni_Sierra Leona',
#  'Bistrita_Rumania',
#  'Haninge_Suecia',
#  'Ilorin_Nigeria',
#  'Wheeling_Estados Unidos',
#  'Baqubah_Irak',
#  'Amol_Irán',
#  'Liaoyang_China',
#  'Fuenlabrada_España',
#  'Lismore_Australia',
#  'Moers_Alemania',
#  'Ipiales_Colombia',
#  'Pernik_Bulgaria',
#  'Morelia_México',
#  'Algonquin_EE. UU.',
#  'St. Catharines_Canada',
#  'Valdemoro_España',
#  'San Angelo_Estados Unidos',
#  'Powder Springs_EE. UU.',
#  'Gladbeck_Alemania',
#  'Severodvinsk_Rusia',
#  'Yibin_China',
#  'Padang_Indonesia',
#  'Odense_Dinamarca',
#  'Antibes_Francia',
#  'Randers_Dinamarca',
#  'San Justo_Argentina',
#  'Charlotte_Estados Unidos',
#  'Cambridge_Estados Unidos',
#  'Bhatpara_India',
#  'Mecca_Arabia Saudí',
#  'Sugar Land_EE. UU.',
#  'Coimbatore_India',
#  'Ningbo_China',
#  'Dumai_Indonesia',
#  'Normal_Estados Unidos',
#  'Ain Oussera_Argelia',
#  'Gothenburg_Suecia',
#  'Milpa Alta_México',
#  'Man_Costa de Marfil',
#  'Annemasse_Francia',
#  'Bagnolet_Francia',
#  'Wuhan_China',
#  'Taixing_China',
#  'Sheboygan_EE. UU.',
#  'Shijiazhuang_China',
#  'Bolzano_Italia',
#  'Medford_EE. UU.',
#  'San Ramon_EE. UU.',
#  'Quimper_Francia',
#  'Ponferrada_España',
#  'Rotterdam_Países Bajos',
#  'Mbinga_Tanzania',
#  'Aylesbury_Reino Unido',
#  'Bolingbrook_Estados Unidos',
#  'Kwangju_Corea del Sur',
#  'Potsdam_Alemania',
#  'Escondido_Estados Unidos',
#  'Valparaíso_Chile',
#  'Fes_Marruecos',
#  'Binjai_Indonesia',
#  'Makhachkala_Rusia',
#  'Jingdezhen_China',
#  'Teziutlán_México',
#  'Guilin_China',
#  'Royal Oak_Estados Unidos',
#  'Wasquehal_Francia',
#  'Felahiye_Turquía',
#  'Clovis_Estados Unidos',
#  'Annapolis_EE. UU.',
#  'Westminster_Estados Unidos',
#  'Bolingbrook_EE. UU.',
#  'Plainfield_EE. UU.',
#  'Warrnambool_Australia',
#  'Thies Nones_Senegal',
#  'Iquique_Chile',
#  'Homestead_Estados Unidos',
#  'Istres_Francia',
#  'Tiruchchirappalli_India',
#  'Fargo_Estados Unidos',
#  'Wellington_Nueva Zelanda',
#  'Turin_Italia',
#  'Vigo_España',
#  'Shahjahanpur_India',
#  'Jamundí_Colombia',
#  'Freiburg_Alemania',
#  'Oshawa_Canada',
#  'Sassari_Italia',
#  'Glenview_Estados Unidos',
#  'New Braunfels_EE. UU.',
#  'Solihull_Reino Unido',
#  'La Chapelle-sur-Erdre_Francia',
#  'Clovis_EE. UU.',
#  'Sevran_Francia',
#  'Moa_Cuba',
#  'Chaville_Francia',
#  'Langen_Alemania',
#  'Guaynabo_Puerto Rico',
#  'Butare_Ruanda',
#  'Colombes_Francia',
#  'Líbano_Estados Unidos',
#  'Limoges_Francia',
#  'Provo_Estados Unidos',
#  'Middlesbrough_Reino Unido',
#  'Licheng_China',
#  'Honolulu_EE. UU.',
#  'Tampa_Estados Unidos',
#  'Heerlen_Países Bajos',
#  'Sangli_India',
#  'Purmerend_Países Bajos',
#  'High Wycombe_Reino Unido',
#  'Chevilly-Larue_Francia',
#  'Draper_Estados Unidos',
#  'La Rochelle_Francia',
#  'Guayana_Venezuela',
#  'Xinshi_China',
#  'Loudi_China',
#  'Basildon_Reino Unido',
#  'Hastings_Reino Unido',
#  'Pacoima_EE. UU.',
#  'Fayún_Egipto',
#  'New Albany_Estados Unidos',
#  'Porto Alegre_Brasil',
#  'Salina Cruz_México',
#  'Naperville_Estados Unidos',
#  'Germantown_EE. UU.',
#  'Caçador_Brasil',
#  'Gómel_Bielorrusia',
#  'Bergerac_Francia',
#  'Campeche_México',
#  'Irwin_EE. UU.',
#  'Mosquera_Colombia',
#  'Brentwood_Estados Unidos',
#  'Brikama_República de Gambia',
#  'Coari_Brasil',
#  'Yambol_Bulgaria',
#  'Thanjavur_India',
#  'Anshan_China',
#  'Cubuk_Turquía',
#  'Tinley Park_Estados Unidos',
#  'Palmerston_Australia',
#  'Nom Pen_Camboya',
#  'Açu_Brasil',
#  'Dar Chioukh_Argelia',
#  'Centurion_SudAfrica',
#  'Dundee_Reino Unido',
#  'North Hills_EE. UU.',
#  ...}

# %%
# Create a dictionary to map node identifiers to node IDs
node_to_id = {node: i for i, node in enumerate(nodes)}

from collections import defaultdict
# Initialize an adjacency list for the graph
graph = defaultdict(set)

# Create edges between nodes
for index, row in df.iterrows():
    start_node = row["start_node"]
    end_node = row["end_node"]
    graph[node_to_id[start_node]].add(node_to_id[end_node])
    graph[node_to_id[end_node]].add(node_to_id[start_node])

# %%
id_to_node = {i: node for i, node in enumerate(nodes)}

# %%
graph[node_to_id["Arbil_Irak"]]
# Out:
# {519,
#  798,
#  1127,
#  1330,
#  1355,
#  1507,
#  1545,
#  1572,
#  1625,
#  1879,
#  2148,
#  2406,
#  2526,
#  2726,
#  2937,
#  3367,
#  3403,
#  3869}

# %%
from collections import deque


def bfs(graph, start_node, end_node, num_paths=3):
    queue = deque([(start_node, [start_node], 0)])
    shortest_paths = []

    while queue:
        current_node, current_path, current_length = queue.popleft()

        if current_node == end_node:
            shortest_paths.append((current_path, current_length))
            if len(shortest_paths) == num_paths:
                break
            continue
        
        for neighbor in graph[current_node]:
            if neighbor in current_path:
                continue
            new_path = current_path + [neighbor]
            queue.append((neighbor, new_path, current_length + 1))

    return shortest_paths


# Perform BFS starting from a specific node
start_node = node_to_id["Venice_Italia"]
end_node = node_to_id["Arbil_Irak"]
routes = bfs(graph, start_node, end_node)
for route, path_len in routes:
    print(f"path length: {path_len}")
    for node in route:
        print(id_to_node[node])
    print("---------")
# Out:
# path length: 2
# Venice_Italia
# Caguas_Puerto Rico
# Arbil_Irak
# ---------
# path length: 2
# Venice_Italia
# Chicago_EE. UU.
# Arbil_Irak
# ---------
# path length: 2
# Venice_Italia
# Los Angeles_EE. UU.
# Arbil_Irak
# ---------

# %%
import joblib
joblib.dump(graph, "graph.pkl")
# Out:
# ['graph.pkl']
